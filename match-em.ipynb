# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np
import base64
from numpy.random import default_rng
import random


rng= np.random.default_rng
#defines the random number generator utilized to index values 

CusTrans = pd.read_csv("../input/h-and-m-personalized-fashion-recommendations/transactions_train.csv")
CusAge = pd.read_csv('../input/customer-ages/CUS CLEANED AGE 2024253035.csv')
article= pd.read_csv("../input/fuckarticle/artTestt.csv")

ra = pd.merge(CusTrans,CusAge, on=['customer_id'], how='inner')
res = pd.merge(ra,article, on=['article_id'], how='inner')

length_of_dataset= len(res)

list_index_vals=[]

x_count=0

for i in range(0,420948):
    list_index_vals.append(x_count)
    x_count=x_count+1
    
print(length_of_dataset)


res.insert(loc=1,
          column= "Random Index Number",
          value=random.sample(list_index_vals,420948)
           
          )
#     random.sample())
print(res)

res.to_csv("new.csv", index=False)
# Out:
# 420948
#              t_dat  Random Index Number  \
# 0       2018-09-20               387198
# 1       2018-09-24               310876
# 2       2018-11-05               185069
# 3       2018-11-05                48959
# 4       2018-12-24                29002
# ...            ...                  ...
# 420943  2020-09-22               416102
# 420944  2020-09-22               401865
# 420945  2020-09-22               230629
# 420946  2020-09-22               130733
# 420947  2020-09-22               237612
#
#                                               customer_id  article_id  \
# 0       000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   663713001
# 1       000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   663713001
# 2       1385e5f3a2d3dbd21237f91faf81254a6d96de31b07b0b...   663713001
# 3       1385e5f3a2d3dbd21237f91faf81254a6d96de31b07b0b...   663713001
# 4       03f57953f2d4922143a957d94b0a79ee2b9b87609f2dc5...   663713001
# ...                                                   ...         ...
# 420943  0e69d1a90e963003d8725d3b1414273b70e06395340a10...   894508001
# 420944  0ed00f7991fb59d570e7adca5ca2ee15b4ef2ce63062ac...   881244006
# 420945  0f10ca98dd4cea99fdaa7bc2d3927ec1918bf202516017...   937138001
# 420946  1111ca5555ad747c35d538bb1c3128f4aaab77094afff7...   909179001
# 420947  112a0940cfd3aef99e3ac744c7e7e6abf1fff78fe2fecc...   867994008
#
#            price  sales_channel_id  FN club_member_status  age  \
# 0       0.050831                 2   0                  1   24
# 1       0.050831                 2   0                  1   24
# 2       0.050831                 2   0                  1   25
# 3       0.050831                 2   0                  1   25
# 4       0.035576                 1   0                  1   25
# ...          ...               ...  ..                ...  ...
# 420943  0.006763                 1   0                  1   35
# 420944  0.033881                 2   0                  1   35
# 420945  0.016932                 2   0                  1   20
# 420946  0.045746                 2   0                  1   24
# 420947  0.061000                 1   1                  1   24
#
#                                               postal_code product_type_name
# 0       64f17e6a330a85798e4998f62d0930d14db8db1c054af6...    Underwear body
# 1       64f17e6a330a85798e4998f62d0930d14db8db1c054af6...    Underwear body
# 2       9d40652a815cf6af4fbabde79f9ec7c4d30f94543279cd...    Underwear body
# 3       9d40652a815cf6af4fbabde79f9ec7c4d30f94543279cd...    Underwear body
# 4       01d981001dcde6d46f39f8e9f7fefa321120c78e0f9941...    Underwear body
# ...                                                   ...               ...
# 420943  2c29ae653a9282cce4151bd87643c907644e09541abc28...            Shorts
# 420944  bb107e71ed99ce4bc9fdcfdafadc611eb2bed38d638893...          Trousers
# 420945  2c3ac2e2ba311ea0287d9bdd940292a49d78fc5c86a272...          Bracelet
# 420946  be963de687a4efd82b9ad21749af651d8f2908f815085f...             Boots
# 420947  2c29ae653a9282cce4151bd87643c907644e09541abc28...            Jacket
#
# [420948 rows x 11 columns]
